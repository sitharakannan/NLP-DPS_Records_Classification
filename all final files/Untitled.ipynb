# %%
import pandas as pd

# %%
df = pd.read_csv('final.csv')

# %%
from sklearn.utils import shuffle
#df = shuffle(df)
print df.head()
print df.shape
# Out:
#                                              Summary  label
# 0  Unknown suspects entered into several possible...      2
# 1  A staff member reported that a computer monito...      2
# 2                       A suspect removed a bicycle.      2
# 3  A student reported that another student posted...      2
# 4  A student reported that a suspect is sharing n...      2
# (1293, 2)

# %%
new_df=pd.DataFrame(columns = ["Summary", "Label"])
rows = []
#train = train[:1300]
for index,row in df.iterrows(): 
    print '{'
    print '\t"label":'+'"'+str(row['label'])+'",'
    print '\t"data":'+'"'+str(row['Summary'])+'"'
    print '},'
    rows.append((str(row['Summary']),str(row['label'])))
new_df=pd.DataFrame(rows,columns = ["Incident", "Summary", "label"])
print new_df.head()
new_df.to_csv("Final_dataset.csv")
# Out:
# {
# 	"label":"2",
# 	"data":"Unknown suspects entered into several possible unlocked rooms and removed students personal property. No forced entry was discovered."
# },
# {
# 	"label":"2",
# 	"data":"A staff member reported that a computer monitor, keyboard and power strip had been placed on the floor inside an unsecured office at the location. No property was removed."
# },
# {
# 	"label":"2",
# 	"data":"A suspect removed a bicycle."
# },
# {
# 	"label":"2",
# 	"data":"A student reported that another student posted a statement on a social media site that caused her to believe the subject may attempt to harm herself. The second student was subsequently determined to be unharmed and with her mother."
# },
# {
# 	"label":"2",
# 	"data":"A student reported that a suspect is sharing nude photographs of her on social media without her permission."
# },
# {
# 	"label":"3",
# 	"data":"A suspect who was observed harassing students at the location was issued a University "stay away" letter."
# ...
